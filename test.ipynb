# %%
import pandas as pd
import ultralytics
import torch

# %%
df = pd.read_csv(r"runs\detect\train\results.csv")
df.tail()
# Out:
#     epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 45     46  2661.85         0.49551         0.37451         1.01221
# 46     47  2717.52         0.48516         0.36789         1.00222
# 47     48  2773.68         0.47152         0.34925         0.99270
# 48     49  2829.36         0.47807         0.34312         0.99642
# 49     50  2885.09         0.48163         0.34055         0.99687
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 45               0.87358            0.86243           0.91571
# 46               0.88797            0.86061           0.91994
# 47               0.87986            0.86957           0.92019
# 48               0.88858            0.85862           0.92374
# 49               0.88512            0.86252           0.92191
#
#     metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 45              0.77675       0.65993       0.66123       1.13920  0.000057
# ...

# %%
# Check versions
print(ultralytics.__version__)
print(torch.__version__)         
print(torch.version.cuda)       
print(torch.cuda.is_available()) 
print(torch.cuda.get_device_name(0))
# Out:
# 8.3.203
# 2.5.1+cu121
# 12.1
# True
# NVIDIA GeForce RTX 3050 6GB Laptop GPU

# %%
# make test dataset from valid dataset
# import os
# import random
# import shutil

# # path dataset
# base_dir = "dataset"
# valid_img = os.path.join(base_dir, "valid/images")
# valid_lbl = os.path.join(base_dir, "valid/labels")

# # path test
# test_img = os.path.join(base_dir, "test/images")
# test_lbl = os.path.join(base_dir, "test/labels")

# # buat folder test
# os.makedirs(test_img, exist_ok=True)
# os.makedirs(test_lbl, exist_ok=True)

# # ambil 20% data validasi untuk test
# all_imgs = os.listdir(valid_img)
# n_test = int(0.2 * len(all_imgs))  # 20%
# test_files = random.sample(all_imgs, n_test)

# # pindahkan file
# for img_file in test_files:
#     # pindahkan image
#     shutil.move(os.path.join(valid_img, img_file),
#                 os.path.join(test_img, img_file))
    
#     # pindahkan label (nama file sama, hanya beda folder & ekstensi .txt)
#     label_file = img_file.rsplit(".", 1)[0] + ".txt"
#     if os.path.exists(os.path.join(valid_lbl, label_file)):
#         shutil.move(os.path.join(valid_lbl, label_file),
#                     os.path.join(test_lbl, label_file))
